# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
image1 = cv2.imread('first.png', cv2.IMREAD_COLOR)
image2 = cv2.imread('second.png', cv2.IMREAD_COLOR)

plt.imshow(image1)
plt.show()
plt.imshow(image2)
plt.show()

# %%
sumImage = image2 + image1
plt.imshow(sumImage)
plt.show()
